# %%
import requests
import json
import os
from dotenv import load_dotenv

load_dotenv()

# retrieve secrets from .env file
CLINET_ID = os.getenv('CLIENT_ID')
API_KEY = os.getenv('API_KEY')

# %% [markdown]
# Retrieving businesses around said location

# %%
def business_search(location: str) -> list:
    ENDPOINT = "https://api.yelp.com/v3/businesses/search"
    HEADERS = {'Authorization' : 'bearer %s' % API_KEY}

    # Define Parameters
    PARAMETERS = {'term': 'food',
                'limit': 50,
                'radius': 2000,
                'location': 'Singapore ' + location}

    # Request to Yelp API
    response = requests.get(url = ENDPOINT,
                            params = PARAMETERS,
                            headers = HEADERS)
    
    # Convert to JSON String
    business_data = response.json()

    return business_data['businesses']

# %%
business_search("Bukit Timah")
# Out:
# [{'id': 'yJMuhAnzoNCWjgIfyEU4fA',
#   'alias': 'penang-kitchen-singapore',
#   'name': 'Penang Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R_Z7_KNwmP-Vz17JDsIWbQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/penang-kitchen-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 7,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'indonesian', 'title': 'Indonesian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 1.32331, 'longitude': 103.8105},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '5 Coronation Rd',
#    'address2': '#01-05 Coronation Arcade',
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '269406',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['5 Coronation Rd',
#     '#01-05 Coronation Arcade',
#     'Singapore 269406',
#     'Singapore']},
#   'phone': '+6564666193',
#   'display_phone': '+65 6466 6193',
#   'distance': 823.8238339813938},
#  {'id': 'cySPns5ww4pllQz_9oYMvw',
#   'alias': 'the-summit-nus-bukit-timah-campus-singapore',
#   'name': 'The Summit @ NUS Bukit Timah Campus',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mvjmfd_9Eb6gHexocmeaGA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-summit-nus-bukit-timah-campus-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 1,
#   'categories': [{'alias': 'food', 'title': 'Food'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 1.31831, 'longitude': 103.8168335},
#   'transactions': [],
#   'location': {'address1': 'Faculty of Law, National University of Singapore',
#    'address2': '469G Bukit Timah Road',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '259776',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['Faculty of Law, National University of Singapore',
#     '469G Bukit Timah Road',
#     'Singapore 259776',
#     'Singapore']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1714.9869700773795},
#  {'id': 'NC8urfeYsW5Juu6oTZeqbg',
#   'alias': 'fratini-la-trattoria-singapore',
#   'name': 'Fratini La Trattoria',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PeygS0oxFdKgF1c-Bicmeg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fratini-la-trattoria-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 9,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 1.3312401, 'longitude': 103.8070908},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '10 Greenwood Avenue',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '289201',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['10 Greenwood Avenue',
#     'Singapore 289201',
#     'Singapore']},
#   'phone': '+6564682868',
#   'display_phone': '+65 6468 2868',
#   'distance': 577.6163336706402},
#  {'id': 'HASO8wsJjyIEzf-g_EjeNg',
#   'alias': 'my-cosy-corner-singapore',
#   'name': 'My Cosy Corner',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yPOH9W2FGYHrUsLDYiN2Bw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/my-cosy-corner-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 12,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.32384, 'longitude': 103.80996},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '587 Bukit Timah Road',
#    'address2': '#02-02',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '269707',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['587 Bukit Timah Road',
#     '#02-02',
#     'Singapore 269707',
#     'Singapore']},
#   'phone': '+6564638286',
#   'display_phone': '+65 6463 8286',
#   'distance': 742.1377301190446},
#  {'id': 'HIYZSMQFBURCBk9z-I0m0g',
#   'alias': 'fat-belly-singapore',
#   'name': 'Fat Belly',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KgAxIRc-gakWiNnFXyUIug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fat-belly-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 2,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 1.32270138035359, 'longitude': 103.813737183809},
#   'transactions': [],
#   'location': {'address1': '10 Jln Serene',
#    'address2': '#01-04',
#    'address3': 'Serene Centre',
#    'city': 'Singapore',
#    'zip_code': '258748',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['10 Jln Serene',
#     '#01-04',
#     'Serene Centre',
#     'Singapore 258748',
#     'Singapore']},
#   'phone': '+6563142247',
#   'display_phone': '+65 6314 2247',
#   'distance': 1177.7291902178188},
#  {'id': '-bk37dWkHuFE9ro_MfywPA',
#   'alias': 'siti-nur-liyana-nasi-lemak-singapore',
#   'name': 'Siti Nur Liyana Nasi Lemak',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sDsyyqxiln-CsFzKKO8m3Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/siti-nur-liyana-nasi-lemak-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 1,
#   'categories': [{'alias': 'halal', 'title': 'Halal'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 1.32417217955116, 'longitude': 103.814090564847},
#   'transactions': [],
#   'location': {'address1': '2 Adam Road',
#    'address2': 'Stall 14, Adam Road Food Centre',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '289876',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['2 Adam Road',
#     'Stall 14, Adam Road Food Centre',
#     'Singapore 289876',
#     'Singapore']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1162.176601466475},
#  {'id': 'JG3Yw6z48y6Eyi0DnN19tQ',
#   'alias': 'corner-house-singapore',
#   'name': 'Corner House',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gFkghVixFQfbCtV66MZYeA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/corner-house-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 29,
#   'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 1.31514424750543, 'longitude': 103.815374672413},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '1 Cluny Rd',
#    'address2': 'EJH Corner House',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '259569',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['1 Cluny Rd',
#     'EJH Corner House',
#     'Singapore 259569',
#     'Singapore']},
#   'phone': '+6564691000',
#   'display_phone': '+65 6469 1000',
#   'distance': 1814.2693133082912},
#  {'id': 'CQre-Nio1uQ_lM8NcXnDUQ',
#   'alias': 'japanese-cuisine-stall-singapore',
#   'name': 'Japanese Cuisine Stall',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kYRBneA9U9x3qpfL2dfiXQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/japanese-cuisine-stall-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 1,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.32371, 'longitude': 103.81052},
#   'transactions': [],
#   'location': {'address1': 'Hwa Chong Institution College Canteen',
#    'address2': 'Bukit Timah Road 661',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '269734',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['Hwa Chong Institution College Canteen',
#     'Bukit Timah Road 661',
#     'Singapore 269734',
#     'Singapore']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 218.41264157969687},
#  {'id': '_OetgkjazTsU3e_ORkaSmw',
#   'alias': 'brazil-churrasco-singapore-2',
#   'name': 'Brazil Churrasco',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zX5uagqWFIUvcsgl1kc2Rw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brazil-churrasco-singapore-2?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 18,
#   'categories': [{'alias': 'brazilian', 'title': 'Brazilian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 1.33084, 'longitude': 103.79497},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '14/16 Sixth Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '276476',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['14/16 Sixth Ave', 'Singapore 276476', 'Singapore']},
#   'phone': '+6564631923',
#   'display_phone': '+65 6463 1923',
#   'distance': 1092.6060037795864},
#  {'id': 'YLZAVINCWOypAPrvc4GrLA',
#   'alias': 'ghim-moh-market-singapore',
#   'name': 'Ghim Moh Market',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s0QyxITIo0Eho8GVk-Rvfw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ghim-moh-market-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 15,
#   'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 1.3111178897203, 'longitude': 103.78848076426},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '20 Ghim Moh Road',
#    'address2': None,
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['20 Ghim Moh Road', 'Singapore', 'Singapore']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2453.089527426868},
#  {'id': 'zbvn7fc_Lso9EGFC1_RYBg',
#   'alias': 'riders-cafe-singapore',
#   'name': 'Riders Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8vpX0GOuafKgkUsegzY6kg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/riders-cafe-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 25,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.34302, 'longitude': 103.79722},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Bukit Timah Saddle Club',
#    'address2': '51 Fairways Drive',
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '286965',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['Bukit Timah Saddle Club',
#     '51 Fairways Drive',
#     'Singapore 286965',
#     'Singapore']},
#   'phone': '+6564669819',
#   'display_phone': '+65 6466 9819',
#   'distance': 1947.4048495076042},
#  {'id': 'ziiNJ8JXZ_gs6PNyzUTkWA',
#   'alias': 'food-r-us-singapore',
#   'name': 'Food R Us',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/59AmK550puTKWy9n97psQg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/food-r-us-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 6,
#   'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 1.31826393181907, 'longitude': 103.807827524261},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3 Queens Rd',
#    'address2': '#02-171',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '260003',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['3 Queens Rd',
#     '#02-171',
#     'Singapore 260003',
#     'Singapore']},
#   'phone': '+6564733822',
#   'display_phone': '+65 6473 3822',
#   'distance': 1043.5384689369687},
#  {'id': 'W9D02VQB1gkYTaOwrK7W5Q',
#   'alias': 'yong-chai-chicken-rice-singapore',
#   'name': 'Yong Chai Chicken Rice',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5laQy2nJ1A-aws_rFtujOw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yong-chai-chicken-rice-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 2,
#   'categories': [{'alias': 'food', 'title': 'Food'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 1.32331, 'longitude': 103.8105011},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '5 Coronation Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '269406',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['5 Coronation Rd', 'Singapore 269406', 'Singapore']},
#   'phone': '+6564689859',
#   'display_phone': '+65 6468 9859',
#   'distance': 819.8455185746009},
#  {'id': 'lqVHs-C3RlZEdrg5pCgOiQ',
#   'alias': 'caruso-singapore',
#   'name': 'Caruso',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u5nWPZkaoJGGpu6s6DcZKA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/caruso-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 4,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 1.33073511695541, 'longitude': 103.795855897298},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '791 Bukit Timah Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '269764',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['791 Bukit Timah Rd', 'Singapore 269764', 'Singapore']},
#   'phone': '+6564697508',
#   'display_phone': '+65 6469 7508',
#   'distance': 1002.2027477105505},
#  {'id': 'ukt4MFLf8IpsI420CJCMkA',
#   'alias': 'la-petite-cuisine-singapore-2',
#   'name': 'La Petite Cuisine',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/D4RsIkjkCUr4c80pxYq4ww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-petite-cuisine-singapore-2?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 18,
#   'categories': [{'alias': 'french', 'title': 'French'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 1.32259724554242, 'longitude': 103.813648804894},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '10 Jalan Serene',
#    'address2': '#01-05 Serene Centre',
#    'address3': '#01-05',
#    'city': 'Singapore',
#    'zip_code': '258748',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['10 Jalan Serene',
#     '#01-05 Serene Centre',
#     '#01-05',
#     'Singapore 258748',
#     'Singapore']},
#   'phone': '+6563143173',
#   'display_phone': '+65 6314 3173',
#   'distance': 1173.274847153002},
#  {'id': 'iyDqgTt373VERoXjQNXuHg',
#   'alias': 'atlas-coffeehouse-singapore',
#   'name': 'Atlas Coffeehouse',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RXjdcqDM273hBjG5wK4nBA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/atlas-coffeehouse-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 19,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.3229, 'longitude': 103.812},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': "6 Duke's Rd",
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '268886',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ["6 Duke's Rd", 'Singapore 268886', 'Singapore']},
#   'phone': '+6563142674',
#   'display_phone': '+65 6314 2674',
#   'distance': 991.7096972233326},
#  {'id': '8HjUivQ9od_978vJ4crPDA',
#   'alias': 'le-wu-cafe-singapore',
#   'name': 'Le Wu Cafe',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/G2mqszdjGCFoAW3wT1KJeA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/le-wu-cafe-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 6,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.32293323856371, 'longitude': 103.811889751633},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '551 Bukit Timah Road',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '269692',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['551 Bukit Timah Road',
#     'Singapore 269692',
#     'Singapore']},
#   'phone': '+6582287394',
#   'display_phone': '+65 8228 7394',
#   'distance': 980.1270850117088},
#  {'id': 'iYPL0oePzFohBQexVaxT-g',
#   'alias': 'peperoni-pizzeria-singapore',
#   'name': 'Peperoni Pizzeria',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-SrdwinQ7NS0vk9zvQTYWg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/peperoni-pizzeria-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 21,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.33128, 'longitude': 103.8071899},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '6 Greenwood Avenue',
#    'address2': 'Hillcrest Park',
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '289195',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['6 Greenwood Avenue',
#     'Hillcrest Park',
#     'Singapore 289195',
#     'Singapore']},
#   'phone': '+6564656556',
#   'display_phone': '+65 6465 6556',
#   'distance': 608.0507473595549},
#  {'id': 'qvxG7AdJXmaYPa76jWMSDg',
#   'alias': 'mays-kopi-bar-singapore',
#   'name': "May's Kopi Bar",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D_DcvL7f1W8x4XLZwnQuBA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mays-kopi-bar-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 2,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 1.33049181485909, 'longitude': 103.795043186508},
#   'transactions': [],
#   'location': {'address1': '22 Sixth Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '276480',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['22 Sixth Ave', 'Singapore 276480', 'Singapore']},
#   'phone': '+6567624616',
#   'display_phone': '+65 6762 4616',
#   'distance': 1073.7373743224305},
#  {'id': '-ioBOWd5wtGqIK8Av4plCw',
#   'alias': 'shin-yuu-japanese-restaurant-singapore',
#   'name': 'Shin Yuu Japanese Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/16SumORIRoW_sUHdkmwjvQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shin-yuu-japanese-restaurant-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 7,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 1.3313031, 'longitude': 103.8068598},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '16 Greenwood Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '289209',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['16 Greenwood Ave', 'Singapore 289209', 'Singapore']},
#   'phone': '+6567634939',
#   'display_phone': '+65 6763 4939',
#   'distance': 592.252732162214},
#  {'id': 'Mt5OYuQRTjd53r0BWTmJWg',
#   'alias': 'sanpoutei-ramen-singapore',
#   'name': 'Sanpoutei Ramen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C8irUP8vFRrWj6cWSyFsGA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sanpoutei-ramen-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 17,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.31134388561304, 'longitude': 103.795740263256},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '253 Holland Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '278983',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['253 Holland Ave', 'Singapore 278983', 'Singapore']},
#   'phone': '+6564637277',
#   'display_phone': '+65 6463 7277',
#   'distance': 1949.673864636349},
#  {'id': '8TzRaat2XHAoKtQsHN1LeQ',
#   'alias': 'top-seafood-singapore',
#   'name': 'Top Seafood',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G7wLjvLGAGmqL3Y9h0UmXQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/top-seafood-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 1,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 1.3308901, 'longitude': 103.7950134},
#   'transactions': [],
#   'location': {'address1': '12 Sixth Avenue',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '276475',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['12 Sixth Avenue', 'Singapore 276475', 'Singapore']},
#   'phone': '+6568751847',
#   'display_phone': '+65 6875 1847',
#   'distance': 1089.6869409679275},
#  {'id': 'Xr0TPGySu_02UQQ1GufRxg',
#   'alias': 'the-little-diner-singapore',
#   'name': 'The Little Diner',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/g7yI6JB7LG-sJl38G_gTDg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-little-diner-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 16,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 1.33115, 'longitude': 103.79624},
#   'transactions': [],
#   'location': {'address1': '789 Bukit Timah Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '269763',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['789 Bukit Timah Rd', 'Singapore 269763', 'Singapore']},
#   'phone': '+6564664088',
#   'display_phone': '+65 6466 4088',
#   'distance': 990.4381878943638},
#  {'id': 'iJQ44KoEVXD_W1yg1CKn5g',
#   'alias': 'torikin-singapore',
#   'name': 'Torikin',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/avBU1GRDmgQ4Dpm5g61mfw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/torikin-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 1,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.32318, 'longitude': 103.81122},
#   'transactions': [],
#   'location': {'address1': 'Crown Centre',
#    'address2': '557 Bukit Timah Rd, #01-14/15/16',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '269694',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['Crown Centre',
#     '557 Bukit Timah Rd, #01-14/15/16',
#     'Singapore 269694',
#     'Singapore']},
#   'phone': '+6564655908',
#   'display_phone': '+65 6465 5908',
#   'distance': 899.5819105951232},
#  {'id': 'j28CBGZ78G0uApo0f9LjaQ',
#   'alias': 'claudes-singapore',
#   'name': "Claude's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_DPXNir3d40G9rCPlrBiVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/claudes-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 2,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.33135, 'longitude': 103.80689},
#   'transactions': [],
#   'location': {'address1': '14 Greenwood Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '289206',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['14 Greenwood Ave', 'Singapore 289206', 'Singapore']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 595.5561853712389},
#  {'id': '90B9WfZFNAw_BKL0PHGJwQ',
#   'alias': 'empress-road-food-centre-singapore',
#   'name': 'Empress Road Food Centre',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_LGIze0JQV7Ccskfmh5GXQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/empress-road-food-centre-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 3,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 1.31625, 'longitude': 103.8056107},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '7 Empress Road',
#    'address2': 'Holland',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '260007',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['7 Empress Road',
#     'Holland',
#     'Singapore 260007',
#     'Singapore']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1178.0268634054255},
#  {'id': 'QxT3goSTkSGWqq4ecId_AQ',
#   'alias': 'relish-by-wild-rocket-singapore',
#   'name': 'Relish By Wild Rocket',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8TKXoq1fZ8qpABhzV8YD2Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/relish-by-wild-rocket-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 20,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 1.32275, 'longitude': 103.8141},
#   'transactions': [],
#   'location': {'address1': '501 Bukit Timah Rd',
#    'address2': '#02-01 Cluny Court',
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '259760',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['501 Bukit Timah Rd',
#     '#02-01 Cluny Court',
#     'Singapore 259760',
#     'Singapore']},
#   'phone': '+6567631547',
#   'display_phone': '+65 6763 1547',
#   'distance': 1235.4810265287033},
#  {'id': 'sQ09FSZ6KmjtZOzrgcWO2A',
#   'alias': 'rubato-singapore-2',
#   'name': 'Rubato',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PGWFxVa3No1T-105LzHiuA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rubato-singapore-2?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 12,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.3311847181112, 'longitude': 103.806992320822},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '12 Greenwood Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '289204',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['12 Greenwood Ave', 'Singapore 289204', 'Singapore']},
#   'phone': '+6562523200',
#   'display_phone': '+65 6252 3200',
#   'distance': 589.4728268721249},
#  {'id': 'N9Ih4skj2G1seuYyR67MSQ',
#   'alias': 'selera-rasa-nasi-lemak-singapore',
#   'name': 'Selera Rasa Nasi Lemak',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0oolAzWq5VTWs8Ur3htwbw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/selera-rasa-nasi-lemak-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 15,
#   'categories': [{'alias': 'halal', 'title': 'Halal'},
#    {'alias': 'indonesian', 'title': 'Indonesian'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 1.32405922166741, 'longitude': 103.814087212086},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2 Adam Rd',
#    'address2': 'Food Centre',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '289876',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['2 Adam Rd',
#     'Food Centre',
#     'Singapore 289876',
#     'Singapore']},
#   'phone': '+6598434509',
#   'display_phone': '+65 9843 4509',
#   'distance': 1165.0664291064381},
#  {'id': 'CXGnrNQ_GoNdgnhfPMTRtg',
#   'alias': 'miao-yi-vegetarian-restaurant-singapore',
#   'name': 'Miao Yi Vegetarian Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k4IrBicC9FeGzwxW7jYJkw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/miao-yi-vegetarian-restaurant-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 6,
#   'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 1.324893, 'longitude': 103.809937},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '587 Bukit Timah Road, Coronation Plaza',
#    'address2': '#03-01/02',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '269707',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['587 Bukit Timah Road, Coronation Plaza',
#     '#03-01/02',
#     'Singapore 269707',
#     'Singapore']},
#   'phone': '+6564671331',
#   'display_phone': '+65 6467 1331',
#   'distance': 696.3417957176837},
#  {'id': 'fxQKJjAs7sayW3Zg45kE_g',
#   'alias': 'the-curry-wok-singapore',
#   'name': 'The Curry Wok',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rs-3MfOG7_Sim-2HTzEHIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-curry-wok-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 9,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.32331, 'longitude': 103.8105},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '5 Coronation Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '269406',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['5 Coronation Rd', 'Singapore 269406', 'Singapore']},
#   'phone': '+6564648878',
#   'display_phone': '+65 6464 8878',
#   'distance': 823.8238339813938},
#  {'id': 'cEygLRqDVkYP5__ytn3ybQ',
#   'alias': 'noo-cheng-adam-road-prawn-noodle-singapore-2',
#   'name': 'Noo Cheng Adam Road Prawn Noodle',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uMSJ1EqPW17gLZoEIcswNA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noo-cheng-adam-road-prawn-noodle-singapore-2?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 15,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 1.32413, 'longitude': 103.81419},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2 Adam Rd',
#    'address2': 'Stall 27,Adam Road Food Centre',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '289876',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['2 Adam Rd',
#     'Stall 27,Adam Road Food Centre',
#     'Singapore 289876',
#     'Singapore']},
#   'phone': '+6596937961',
#   'display_phone': '+65 9693 7961',
#   'distance': 1172.8043017205164},
#  {'id': 'n_C0zkPwhUCjjP7bruaXMA',
#   'alias': 'chikuwatei-nishi-singapore',
#   'name': 'Chikuwatei Nishi',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F-vt9hWTjhR2YkgitEF2ng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chikuwatei-nishi-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 1,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 1.3120008830124, 'longitude': 103.794238873563},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '48 Lor Mambong',
#    'address2': '',
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '277699',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['48 Lor Mambong', 'Singapore 277699', 'Singapore']},
#   'phone': '+6567344436',
#   'display_phone': '+65 6734 4436',
#   'distance': 1971.9569533081828},
#  {'id': 'pBewP-7VkB3zV3BIHQSBSA',
#   'alias': 'meat-n-chill-singapore',
#   'name': "MEAT n' CHILL",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dUS-dxINFdI8-YT8lnmQiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/meat-n-chill-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 7,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 1.33163384187516, 'longitude': 103.794992150799},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '805 Bukit Timah Rd',
#    'address2': '#01-04, Sixth Avenue Centre',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '279883',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['805 Bukit Timah Rd',
#     '#01-04, Sixth Avenue Centre',
#     'Singapore 279883',
#     'Singapore']},
#   'phone': '+6562197460',
#   'display_phone': '+65 6219 7460',
#   'distance': 1133.111108313162},
#  {'id': 'pHR9vmwDYmnAKAndfxJmjQ',
#   'alias': 'tao-xiang-kitchen-singapore',
#   'name': 'Tao Xiang Kitchen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NTjEz7uDGpNQqg9APpQcWA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tao-xiang-kitchen-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 2,
#   'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#    {'alias': 'streetvendors', 'title': 'Street Vendors'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.33117141600613, 'longitude': 103.794821021714},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '10E Sixth Avenue',
#    'address2': '#01-01/02',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '276474',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['10E Sixth Avenue',
#     '#01-01/02',
#     'Singapore 276474',
#     'Singapore']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1126.9175657635976},
#  {'id': 'QnNBngo_O97cOhwUCtPeFA',
#   'alias': 'choupinette-singapore',
#   'name': 'Choupinette',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YRtZvTMH0AEfT4q8O43h0A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/choupinette-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 19,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'bistros', 'title': 'Bistros'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.324379, 'longitude': 103.8094803},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '607 Bukit Timah Road',
#    'address2': None,
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '269708',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['607 Bukit Timah Road',
#     'Singapore 269708',
#     'Singapore']},
#   'phone': '+6564660613',
#   'display_phone': '+65 6466 0613',
#   'distance': 669.3344614217746},
#  {'id': '6VvUFM4JoExq7nGT7bE6ag',
#   'alias': 'astons-express-singapore-5',
#   'name': "Aston's Express",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JvjWoT0ndb4CEAxid34SBQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/astons-express-singapore-5?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 1,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 1.33111, 'longitude': 103.7947388},
#   'transactions': [],
#   'location': {'address1': '10E Sixth Ave',
#    'address2': '#01-01/02',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '276474',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['10E Sixth Ave',
#     '#01-01/02',
#     'Singapore 276474',
#     'Singapore']},
#   'phone': '+6567448220',
#   'display_phone': '+65 6744 8220',
#   'distance': 1098.981253877801},
#  {'id': 'XWpAgULCaZH3KmcMxm240g',
#   'alias': 'kuro-kin-japanese-dining-singapore',
#   'name': 'Kuro Kin Japanese Dining',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LjucOWWTngeZq6l2-PiKzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kuro-kin-japanese-dining-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 6,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.33686841079131, 'longitude': 103.793003166046},
#   'transactions': [],
#   'location': {'address1': '200 Turf Club Road',
#    'address2': '#01-27 The Grandstand',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '287994',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['200 Turf Club Road',
#     '#01-27 The Grandstand',
#     'Singapore 287994',
#     'Singapore']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1654.0964286112132},
#  {'id': '8sdmnid02UEE8QGnrcd3Cg',
#   'alias': 'botanico-singapore',
#   'name': 'Botanico',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zaWPkhor_lz1q4LBLMb7VA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/botanico-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 2,
#   'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 1.31757519377393, 'longitude': 103.815409399309},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '50 Cluny Park Rd',
#    'address2': 'Level 2',
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '257488',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['50 Cluny Park Rd',
#     'Level 2',
#     'Singapore 257488',
#     'Singapore']},
#   'phone': '+6562647978',
#   'display_phone': '+65 6264 7978',
#   'distance': 1634.7361233396566},
#  {'id': 'mRL_AQvQjlEoyVpIH98bvA',
#   'alias': 'simply-bread-singapore-3',
#   'name': 'Simply Bread',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FL9ESbD_etaH0pg1uSsqZw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/simply-bread-singapore-3?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 5,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 1.33066, 'longitude': 103.79558},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1 Fifth Ave',
#    'address2': '#01-03',
#    'address3': 'Guthrie House',
#    'city': 'Singapore',
#    'zip_code': '268802',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['1 Fifth Ave',
#     '#01-03',
#     'Guthrie House',
#     'Singapore 268802',
#     'Singapore']},
#   'phone': '+6564667767',
#   'display_phone': '+65 6466 7767',
#   'distance': 1029.5390208275535},
#  {'id': 'fnJaWWfbXjqCFP_h9Gf7Ug',
#   'alias': 'adam-fishball-noodle-singapore',
#   'name': 'Adam Fishball Noodle',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/42ixGDF-_s1cyfYdILexnQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/adam-fishball-noodle-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 2,
#   'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 1.32413, 'longitude': 103.81419},
#   'transactions': [],
#   'location': {'address1': '2 Adam Rd',
#    'address2': 'Stall 25',
#    'address3': 'Adam Food Centre',
#    'city': 'Singapore',
#    'zip_code': '289876',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['2 Adam Rd',
#     'Stall 25',
#     'Adam Food Centre',
#     'Singapore 289876',
#     'Singapore']},
#   'phone': '+6596384934',
#   'display_phone': '+65 9638 4934',
#   'distance': 1172.8043017205164},
#  {'id': 'WdGfgwjXXbAyG389PmRuGQ',
#   'alias': 'gaia-korean-grill-bar-singapore',
#   'name': 'Gaia Korean Grill + Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1HDYtnIZJitQ9aTxp2inRA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gaia-korean-grill-bar-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 2,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 1.31036, 'longitude': 103.79492},
#   'transactions': [],
#   'location': {'address1': '17E Lorong Liput',
#    'address2': 'Holland Village',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '277731',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['17E Lorong Liput',
#     'Holland Village',
#     'Singapore 277731',
#     'Singapore']},
#   'phone': '+6563393313',
#   'display_phone': '+65 6339 3313',
#   'distance': 2061.8618510701913},
#  {'id': 'E-dlyYACz1hP1Ghk9g2V6w',
#   'alias': 'westlake-singapore',
#   'name': 'Westlake',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KYfJG-mc6HZSiE_mFWiMvg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/westlake-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 4,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.31898, 'longitude': 103.8081894},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': "4 Queen's Rd",
#    'address2': '#02-139',
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '260004',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ["4 Queen's Rd",
#     '#02-139',
#     'Singapore 260004',
#     'Singapore']},
#   'phone': '+6564747283',
#   'display_phone': '+65 6474 7283',
#   'distance': 1022.8363985859236},
#  {'id': 'MIIDa_iMci2gU53AyHV2MA',
#   'alias': 'good-good-eating-house-singapore',
#   'name': 'Good Good Eating House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sX_jTPTEQc0ykmVXzT5jOQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/good-good-eating-house-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 1,
#   'categories': [{'alias': 'food', 'title': 'Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.33047, 'longitude': 103.7949677},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '24 Sixth Avenue',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '276481',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['24 Sixth Avenue', 'Singapore 276481', 'Singapore']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1075.6240934133082},
#  {'id': 'KPrdWch1680ihzVe3C-s3w',
#   'alias': 'violet-oons-kitchen-singapore',
#   'name': "Violet Oon's Kitchen",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6-cWlu6pJmBtuPmrh1YTsA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/violet-oons-kitchen-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 28,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'bistros', 'title': 'Bistros'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.33274, 'longitude': 103.79106},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '881 Bukit Timah Road',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '279893',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['881 Bukit Timah Road',
#     'Singapore 279893',
#     'Singapore']},
#   'phone': '+6564685430',
#   'display_phone': '+65 6468 5430',
#   'distance': 1530.938245077153},
#  {'id': '_u9kMIh2yjXmxFxwlZpemg',
#   'alias': 'the-halia-singapore-2',
#   'name': 'The Halia',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tjpRGzjdtcL1V3_QmXs5jA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-halia-singapore-2?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 27,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'halal', 'title': 'Halal'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.311359, 'longitude': 103.814983},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1 Cluny Road,',
#    'address2': 'Ginger Garden',
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '259569',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['1 Cluny Road,',
#     'Ginger Garden',
#     'Singapore 259569',
#     'Singapore']},
#   'phone': '+6584441148',
#   'display_phone': '+65 8444 1148',
#   'distance': 2110.333437953408},
#  {'id': '-rlv7EFjVjeB5cg9RfBZLw',
#   'alias': 'holland-village-market-and-food-centre-singapore',
#   'name': 'Holland Village Market and Food Centre',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z20Mk3e5RWOXd7-vog3PLQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/holland-village-market-and-food-centre-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 7,
#   'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 1.31107, 'longitude': 103.79492},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1 Lorong Mambong',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '277700',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['1 Lorong Mambong', 'Singapore 277700', 'Singapore']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2019.3176216063603},
#  {'id': '4sroIBZMOc1l1DSUsHLcvw',
#   'alias': 'sakurazaka-singapore',
#   'name': 'Sakurazaka',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c-wQBInHuNq3NfQ7TBcwOw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sakurazaka-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 3,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 1.33158, 'longitude': 103.80669},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '24 Greenwood Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Singapore',
#    'zip_code': '289221',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['24 Greenwood Ave', 'Singapore 289221', 'Singapore']},
#   'phone': '+6564630333',
#   'display_phone': '+65 6463 0333',
#   'distance': 613.0852445087316},
#  {'id': 'nhclHWzEN_8Z34JTzB0fCw',
#   'alias': 'cheng-mei-shi-lor-mee-singapore',
#   'name': 'Cheng Mei Shi Lor Mee',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D1ctI-KbXcdX6H9vN-bzTg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cheng-mei-shi-lor-mee-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 1,
#   'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 1.31666994094849, 'longitude': 103.817001342773},
#   'transactions': [],
#   'location': {'address1': '48A Tanglin Halt Road',
#    'address2': '#01-14',
#    'address3': 'Tanglin Halt Market',
#    'city': 'Singapore',
#    'zip_code': '142048',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['48A Tanglin Halt Road',
#     '#01-14',
#     'Tanglin Halt Market',
#     'Singapore 142048',
#     'Singapore']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1835.923050971584},
#  {'id': 'x0mTZTNXSAj34peVy5dnpA',
#   'alias': 'hup-choon-eating-house-singapore',
#   'name': 'Hup Choon Eating House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r84_CPfgDAk8D5EJuGQMiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hup-choon-eating-house-singapore?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8NwQQZhYOk3Lk3HY1sDUfA',
#   'review_count': 8,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 1.33585, 'longitude': 103.78649},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1 Binjai Park',
#    'address2': None,
#    'address3': None,
#    'city': 'Singapore',
#    'zip_code': '589818',
#    'country': 'SG',
#    'state': 'SG',
#    'display_address': ['1 Binjai Park', 'Singapore 589818', 'Singapore']},
#   'phone': '+6564684081',
#   'display_phone': '+65 6468 4081',
#   'distance': 2186.294383926161}]

# %% [markdown]
# Retrieving reviews of said business

# %%
business_id = business_data['businesses'][0]['id']

r_url = "https://api.yelp.com/v3/businesses/" + business_id + "/reviews"    #review request URL creation based on business ID

# Getting Response
response = requests.get(url = r_url,
                        headers = HEADERS)
review_data = response.json()

# Print
print(json.dumps(review_data, indent = 3))
# Out:
# {
#    "reviews": [
#       {
#          "id": "G5rFIgNNV7EsybiEwLiHUA",
#          "url": "https://www.yelp.com/biz/maxwell-food-centre-singapore-3?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&hrid=G5rFIgNNV7EsybiEwLiHUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=8NwQQZhYOk3Lk3HY1sDUfA",
#          "text": "Came by for lunch the other day and it was a tasty experience! Maxwell has a ton of stalls, including the famous Tian Tian.\n\nPicked a random spot to get...",
#          "rating": 5,
#          "time_created": "2022-07-02 23:48:33",
#          "user": {
#             "id": "ZpUI9ze0YlA6nMSHwx3ZYQ",
#             "profile_url": "https://www.yelp.com/user_details?userid=ZpUI9ze0YlA6nMSHwx3ZYQ",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/photo/960pfrAtKtRY4iqnKLyLxQ/o.jpg",
#             "name": "Derek S."
#          }
#       },
#       {
#          "id": "8wh1CBgX2q1JQWBHuZgbLg",
#          "url": "https://www.yelp.com/biz/maxwell-food-centre-singapore-3?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&hrid=8wh1CBgX2q1JQWBHuZgbLg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=8NwQQZhYOk3Lk3HY1sDUfA",
#          "text": "Covered outdoor market - the famous hainanese chicken stall is located here! Unfortunately it looks as though many stalls are vacant or just not opened...",
#          "rating": 5,
#          "time_created": "2022-06-23 09:52:44",
#          "user": {
#             "id": "1CrjGXXlt1hlKOc_rSlUKQ",
#             "profile_url": "https://www.yelp.com/user_details?userid=1CrjGXXlt1hlKOc_rSlUKQ",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/photo/DjEyETOKZ3dw5SiuGCd3sA/o.jpg",
#             "name": "Angela K."
#          }
#       },
#       {
#          "id": "nAnQRx0UqNjUZdlC4VnMpw",
#          "url": "https://www.yelp.com/biz/maxwell-food-centre-singapore-3?adjust_creative=8NwQQZhYOk3Lk3HY1sDUfA&hrid=nAnQRx0UqNjUZdlC4VnMpw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=8NwQQZhYOk3Lk3HY1sDUfA",
#          "text": "This is by far my favourite Hawker Centre I've been to. I heard about an issue with rats falling from the ceiling here, but I will ignore that. I had some...",
#          "rating": 5,
#          "time_created": "2022-07-02 11:21:02",
#          "user": {
#             "id": "1WV-GVAujSK6yCspTFFsgw",
#             "profile_url": "https://www.yelp.com/user_details?userid=1WV-GVAujSK6yCspTFFsgw",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/photo/HHkjVl5y1qE1eWq4-fCHqg/o.jpg",
#             "name": "Carrie M."
#          }
#       }
#    ],
#    "total": 254,
#    "possible_languages": [
#       "en",
#       "de",
#       "fr",
#       "tr",
#       "ja"
#    ]
# }

# %% [markdown]
# Creating Sample Data & Group Choice Function

# %%
sample_data = {business_data['businesses'][0]['name']: {'index': 1, 'likes': [1]},
                business_data['businesses'][1]['name']: {'index': 2, 'likes': [1]},
                business_data['businesses'][2]['name']: {'index': 4, 'likes': [1, 2]},
                business_data['businesses'][3]['name']: {'index': 3, 'likes': [2]},
                business_data['businesses'][4]['name']: {'index': 8, 'likes': [2, 3]},
                business_data['businesses'][5]['name']: {'index': 9, 'likes': [3]},
                business_data['businesses'][6]['name']: {'index': 10, 'likes': [3]},
                }


# with open("sample_data_simplified.json", "w") as f:
#     json.dump(sample_data, f)

sample_data
# Out:
# {'Maxwell Food Centre': {'index': 1, 'likes': [1]},
#  'Holycrab': {'index': 2, 'likes': [1]},
#  'Lau Pa Sat': {'index': 4, 'likes': [1, 2]},
#  "Jacob's Cafe": {'index': 3, 'likes': [2]},
#  'Zhong Guo La Mian Xiao Long Bao': {'index': 8, 'likes': [2, 3]},
#  'Three Good Guys': {'index': 9, 'likes': [3]},
#  'Tai Hwa Pork Noodle': {'index': 10, 'likes': [3]}}

# %%
def group_choice(choices: dict) -> str:
    # Returns most liked restaurant with the least number of dislikes.
    # Only applicable in group setting.
    return sorted(choices, key=lambda x: (len(choices[x]['likes']), choices[x]['index']), reverse=True)[0]


# with open('sample_data_simplified.json') as file:
#     data = json.load(file)

group_choice(sample_data)
# Out:
# 'Zhong Guo La Mian Xiao Long Bao'

# %% [markdown]
# * person1 : 1,2,4 (4 restaurants)
# * person2 : 3,4,8 (8)
# * person3 : 8,9,10 (10)
#
# 4, 8
